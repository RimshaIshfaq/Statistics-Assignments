# %% [markdown]
# # Moments: Mean, Variance, Skew, Kurtosis

# %% [markdown]
# Create a roughly normal-distributed random set of data:

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 100, 10000)

plt.hist(vals, 50)
plt.show()

# %% [markdown]
# The first moment is the mean; this data should average out to about 0:

# %%
np.mean(vals)
# Out:
# 1.3687527286477659

# %% [markdown]
# The second moment is the variance:

# %%
np.var(vals)
# Out:
# 9977.550670827322

# %% [markdown]
# The third moment is skew - since our data is nicely centered around 0, it should be almost 0:

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# -0.030274853420428956

# %% [markdown]
# The fourth moment is "kurtosis", which describes the shape of the tail. For a normal distribution, this is 0:

# %%
sp.kurtosis(vals)
# Out:
# 0.030758701810450706

# %% [markdown]
# ## Activity

# %% [markdown]
# Understanding skew: change the normal distribution to be centered around 10 instead of 0, and see what effect that has on the moments.
#
# The skew is still near zero; skew is associated with the shape of the distribution, not its actual offset in X.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals1 = np.random.normal(10, 100, 10000)

plt.hist(vals1, 50)
plt.show()

# %%
np.mean(vals1)
# Out:
# 9.919312481219798

# %%
np.var(vals1)
# Out:
# 10001.255357947379

# %%
import scipy.stats as sp
sp.skew(vals1)
# Out:
# 0.002529140858805897

# %%
sp.kurtosis(vals1)
# Out:
# 0.07711771859031069

# %% [markdown]
# let's change standard deviation from 100 to 500 and now see

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

vals2 = np.random.normal(10, 500, 10000)

plt.hist(vals2, 50)
plt.show()

# %%
np.mean(vals2)
# Out:
# 13.719884436840022

# %%
np.var(vals2)
# Out:
# 247827.1270705842

# %%
import scipy.stats as sp
sp.skew(vals2)
# Out:
# -0.016533729979275057

# %%
sp.kurtosis(vals2)
# Out:
# 0.011726026968506886
