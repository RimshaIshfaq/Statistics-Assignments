# %% [markdown]
# # Standard Deviation and Variance

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 50.51196797993274

# %%
incomes.var()
# Out:
# 2551.4589092057504

# %% [markdown]
# ## Activity

# %% [markdown]
# Experiment with different parameters on the normal function, and see what effect it has on the shape of the distribution. How does that new shape relate to the standard deviation and variance?

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes1 = np.random.normal(1.0, 50.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes1.std()
# Out:
# 50.3548047141025

# %%
incomes1.var()
# Out:
# 2535.6063577953996

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

incomes2 = np.random.normal(100.0, 5000.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
incomes2.std()
# Out:
# 4941.1063662997885

# %%
incomes2.var()
# Out:
# 24414532.123088297
